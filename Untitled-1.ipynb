# %%
import pandas as pd 
total_linhas = csv["dif_media_custo"].count()

csv = pd.read_csv("plano_saude.csv", sep=',')
custo = csv["custo"].mean()
idade = csv["idade"].mean()


csv["dif_media_idade"] = csv["idade"] - idade
csv["dif_media_custo"] = csv["custo"] - custo

csv["nova"] = (csv["dif_media_custo"] * csv["dif_media_idade"]) / total_linhas - 1

print(csv)


print(custo , idade)
# Out:
#     idade  custo  dif_media_idade  dif_media_custo         nova
# 0      18    871       -24.090909     -1233.181818  2699.770098
# 1      23   1100       -19.090909     -1004.181818  1741.794891
# 2      25   1393       -17.090909      -711.181818  1103.976709
# 3      33   1654        -9.090909      -450.181818   371.051089
# 4      34   1915        -8.090909      -189.181818   138.150263
# 5      43   2100         0.909091        -4.181818    -1.345605
# 6      48   2356         5.909091       251.818182   134.274230
# 7      51   2698         8.909091       593.818182   479.943651
# 8      58   2959        15.909091       854.818182  1235.307288
# 9      63   3000        20.909091       895.818182  1701.794891
# 10     67   3100        24.909091       995.818182  2253.993238
# 2104.181818181818 42.09090909090909
